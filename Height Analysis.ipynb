# %%
import pandas as pd

df = pd.read_csv('height-weight.CSV')
df.tail()
# Out:
#      ind  Height   Weight
# 195  195   65.80   120.84
# 196  196   66.11   115.78
# 197  197   68.24   128.30
# 198  198   68.02   127.47
# 199  199   71.39   127.88

# %%
import pandas as pd
df = pd.read_csv('credit_card_fraud.csv')
df
# Out:
#      Transaction Date and Time  Transaction Amount        Cardholder Name  \
# 0              9/24/2022 13:54              285.88            Shray Soman
# 1              7/24/2020 11:20             1777.32         Lakshit Bakshi
# 2               3/18/2023 1:05             3939.01             Riya Bobal
# 3               1/7/2021 21:53              376.44  Mohanlal Balakrishnan
# 4              12/16/2021 6:22             1687.33            Mannat Rout
# ...                        ...                 ...                    ...
# 7995          12/17/2020 20:36             2214.15         Lakshay Khatri
# 7996             7/4/2022 5:19              675.97        Dharmajan Salvi
# 7997           8/14/2022 19:14              918.28              Alia Sane
# 7998           5/16/2021 18:21             3035.31            Chirag Rege
# 7999            6/14/2023 6:12             3354.36              Alia Bose
#
#                       Card Number (Hashed or Encrypted)  \
# ...
